# %%
import pandas as pd
import numpy as np

# %%
result1=pd.read_excel('18~21년도영화통합(평점반영).xlsx')
result1.head()
# Out:
#         영화명        개봉일       매출액   매출액점유율     관객수   스크린수    상영횟수  대표국적   \
# 0  보헤미안 랩소디 2018-10-31  25.105423   0.044  9224582   1179  204537    미국
# 1        공작 2018-08-08  24.479543   0.024  4974520   1317   99001    한국
# 2   국가부도의 날 2018-11-28  24.152268   0.017  3747952   1180  100804    한국
# 3        코코 2018-01-11  24.044174   0.015  3510017   1177   85925    미국
# 4      아쿠아맨 2018-12-19  24.139493   0.017  3491857   1285   54505    미국
#
#         등급      장르  제작연도  유형       감독      편당관객수      스크린당관객수  네티즌평점  평론가평점
# 0  12세이상관람가    드라마  2018  장편  브라이언 싱어  45.099821  7824.072943   9.42   6.14
# 1  12세이상관람가    드라마  2017  장편      윤종빈  50.247169  3777.160213   6.83   6.93
# 2  12세이상관람가    드라마  2018  장편      최국희  37.180588  3176.230508   8.12   6.50
# 3     전체관람가  애니메이션  2017  장편   리 언크리치  40.849776  2982.172472   9.32   8.00
# 4  12세이상관람가     액션  2018  장편    제임스 완  64.064893  2717.398444   8.36   6.83

# %%
result1.columns
# Out:
# Index(['영화명', '개봉일', '매출액 ', '매출액점유율', '관객수 ', '스크린수 ', '상영횟수 ', '대표국적 ',
#        '등급 ', '장르', '제작연도', '유형', '감독', '편당관객수', '스크린당관객수', '네티즌평점', '평론가평점'],
#       dtype='object')

# %%
result1.shape
# Out:
# (999, 17)

# %%
result2=result1.drop_duplicates(['영화명'],keep='first')

# %%
result2.shape
# Out:
# (979, 17)

# %%
result2=result2.drop(['감독'],axis=1)

# %%
result2
# Out:
#                      영화명        개봉일       매출액   매출액점유율     관객수   스크린수   \
# 0               보헤미안 랩소디 2018-10-31  25.105423   0.044  9224582   1179
# 1                     공작 2018-08-08  24.479543   0.024  4974520   1317
# 2                국가부도의 날 2018-11-28  24.152268   0.017  3747952   1180
# 3                     코코 2018-01-11  24.044174   0.015  3510017   1177
# 4                   아쿠아맨 2018-12-19  24.139493   0.017  3491857   1285
# ..                   ...        ...        ...     ...      ...    ...
# 994               아웃브레이크 2021-07-29  13.122363   0.000      100      5
# 995        엑소시즘: 악령의 눈동자 2021-09-08  13.030248   0.000      100      5
# 996  시니어퀸 : 58년 개띠 여고동창생 2021-05-11  13.448785   0.000       99      1
# 997                  보통날 2021-07-01  12.718896   0.000       98      1
# 998               너는 저편에 2021-07-01  13.337475   0.000       80      5
#
#       상영횟수  대표국적        등급       장르  제작연도  유형      편당관객수      스크린당관객수  네티즌평점  \
# ...

# %%
result2=result2.dropna(axis=0)

# %%
result2.shape
# Out:
# (880, 16)

# %%
result2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 880 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영화명      880 non-null    object
#  1   개봉일      880 non-null    datetime64[ns]
#  2   매출액      880 non-null    float64
#  3   매출액점유율   880 non-null    float64
#  4   관객수      880 non-null    int64
#  5   스크린수     880 non-null    int64
#  6   상영횟수     880 non-null    int64
#  7   대표국적     880 non-null    object
#  8   등급       880 non-null    object
#  9   장르       880 non-null    object
#  10  제작연도     880 non-null    int64
#  11  유형       880 non-null    object
#  12  편당관객수    880 non-null    float64
#  13  스크린당관객수  880 non-null    float64
#  14  네티즌평점    880 non-null    float64
#  15  평론가평점    880 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(5)
# memory usage: 116.9+ KB

# %%
result2.to_excel('Result.xlsx',index=False)
